# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csvpath=Path("../pandas-homework/Resources/whale_returns.csv")
whale_df=pd.read_csv(csvpath, parse_dates=True, infer_datetime_format=True)
whale_df.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
# Count nulls
whale_df["Date"]=pd.to_datetime(whale_df["Date"],  infer_datetime_format=True)
#algo_df.dtypes
whale_df.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_dfc=whale_df.dropna().copy()
#whale_dfc.isnull().sum()
whale_dfc.set_index("Date", inplace=True)
whale_dfc.sort_index(inplace=True)
whale_dfc.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csvpath=Path("../pandas-homework/Resources/algo_returns.csv")
algo_df=pd.read_csv(csvpath, parse_dates=True, infer_datetime_format=True)
algo_df.head()
# Out:
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN
# 3  2014-06-02  0.005692     NaN
# 4  2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df["Date"]=pd.to_datetime(algo_df["Date"],  infer_datetime_format=True)
#algo_df.dtypes
algo_df.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_dfc=algo_df.dropna().copy()
#algo_dfc.isnull().sum()
algo_dfc.set_index("Date", inplace=True)
algo_dfc.sort_index(inplace=True)
algo_dfc.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csvpath=Path("../pandas-homework/Resources/sp500_history.csv")
sp500_df=pd.read_csv(csvpath, parse_dates=True, infer_datetime_format=True)
sp500_df.head()
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df["Date"]=pd.to_datetime(sp500_df["Date"],  infer_datetime_format=True)
sp500_df["Close"]=sp500_df["Close"].str.replace("$","", regex=True)
sp500_df["Close"]=sp500_df["Close"].astype("float")
#sp500_df.dtypes
sp500_df.head()
# Out:
#         Date    Close
# 0 2019-04-23  2933.68
# 1 2019-04-22  2907.97
# 2 2019-04-18  2905.03
# 3 2019-04-17  2900.45
# 4 2019-04-16  2907.06

# %%
# Calculate Daily Returns
sp500_df.set_index("Date", inplace=True)
sp500_dfr=sp500_df.pct_change()
sp500_dfr.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_dfc= sp500_dfr.dropna().copy()
#sp500_dfc.isnull().sum()
sp500_dfc.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_dfc.columns=["SP500"]
sp500_dfc.sort_index(inplace=True)
sp500_dfc.head()
#sp500_dfc.tail()
# Out:
#                SP500
# Date
# 2012-10-01 -0.000872
# 2012-10-02 -0.003611
# 2012-10-03 -0.007123
# 2012-10-04  0.000322
# 2012-10-05  0.003469

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
all_portfolio_returns=pd.concat([sp500_dfc, whale_dfc, algo_dfc ], axis='columns', join='inner')
all_portfolio_returns.head()
# Out:
#                SP500  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03  0.004408                  -0.001266           -0.004981
# 2015-03-04 -0.001195                   0.002230            0.003241
# 2015-03-05  0.014378                   0.004016            0.004076
# 2015-03-06 -0.003929                  -0.007905           -0.003574
# 2015-03-09  0.017254                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2
# Date
# 2015-03-03 -0.000949
# 2015-03-04  0.002416
# 2015-03-05  0.004323
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_portfolio_returns.plot(figsize=(20,15), legend=True, title="All Portfolio Returns")
# Out:
# <AxesSubplot:title={'center':'All Portfolio Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns= (1+all_portfolio_returns).cumprod()

# Plot cumulative returns
(cumulative_returns).plot(figsize=(20,15), legend=True, title="Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
all_portfolio_returns.plot.box(figsize=(20,15), legend=True, title="All Portfolio Returns")
(cumulative_returns).plot.box(figsize=(20,15), legend=True, title="Cumulative Returns")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std=all_portfolio_returns.std()
daily_std.sort_values(ascending=False, inplace=True)
daily_std.head(7)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# SP500                          0.008587
# Algo 2                         0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 1                         0.007623
# PAULSON & CO.INC.              0.007026
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500

# daily standard deviation of S&P 500 from the original dataset
#daily_std_sp500= sp500_dfc.std() 

# daily standard deviation of S&P 500 from the concatenated dataset having smaller timeseries
daily_std.loc['SP500'] 



# Determine which portfolios are riskier than the S&P 500

# portfolios are riskier than daily standard deviation of S&P 500 from the original dataset
#daily_std.loc[daily_std> daily_std_sp500.iloc[0]] 

# portfolios are riskier than daily standard deviation of S&P 500 from 
# the concatenated dataset having smaller timeseries
daily_std.loc[daily_std> daily_std.loc['SP500']]
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std=daily_std * np.sqrt(252)
daily_std.head(7)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# SP500                          0.008587
# Algo 2                         0.008341
# SOROS FUND MANAGEMENT LLC      0.007896
# Algo 1                         0.007623
# PAULSON & CO.INC.              0.007026
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_portfolio_rolling_returns= all_portfolio_returns.rolling(window=21).std()
# Plot the rolling standard deviation
all_portfolio_rolling_returns.plot(figsize=(20,15), legend=True, title="21-Day Rolling Returns")
# Out:
# <AxesSubplot:title={'center':'21-Day Rolling Returns'}, xlabel='Date'>

# %%
# Calculate the rolling standard deviation for all portfolios using a 252-day window
all_portfolio_rolling_returns_252= all_portfolio_returns.rolling(window=252).std()
# Plot the rolling standard deviation
all_portfolio_rolling_returns_252.plot(figsize=(20,15), legend=True, title="252-Day Rolling Returns")
# Out:
# <AxesSubplot:title={'center':'252-Day Rolling Returns'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
all_portfolio_correlation = all_portfolio_returns.corr()

# Display de correlation matrix
all_portfolio_correlation
# Out:
#                                 SP500  SOROS FUND MANAGEMENT LLC  \
# SP500                        1.000000                   0.000574
# SOROS FUND MANAGEMENT LLC    0.000574                   1.000000
# PAULSON & CO.INC.            0.013549                   0.699823
# TIGER GLOBAL MANAGEMENT LLC -0.001505                   0.561040
# BERKSHIRE HATHAWAY INC      -0.013856                   0.754157
# Algo 1                      -0.033963                   0.320901
# Algo 2                      -0.002192                   0.826730
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# SP500                                  0.013549                    -0.001505
# SOROS FUND MANAGEMENT LLC              0.699823                     0.561040
# PAULSON & CO.INC.                      1.000000                     0.434308
# TIGER GLOBAL MANAGEMENT LLC            0.434308                     1.000000
# ...

# %%
sns.heatmap(all_portfolio_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance_rolling_algo1=all_portfolio_returns["Algo 1"].rolling(window=60).cov(all_portfolio_returns["SP500"])
#covariance_rolling_algo1

# Calculate variance of S&P 500
variance_rolling_sp500=all_portfolio_returns["SP500"].rolling(window=60).var()
#variance_rolling_sp500

# Computing beta
beta_rolling_algo1=covariance_rolling_algo1/variance_rolling_sp500
# Plot beta trend
beta_rolling_algo1.plot(figsize=(20,15), legend=True, title="60-Day Rolling Beta")
# Out:
# <AxesSubplot:title={'center':'60-Day Rolling Beta'}, xlabel='Date'>

# %%
#beta vs correlation
sns.lmplot(x='SP500', y='Algo 1', data=all_portfolio_returns, aspect=1.5, fit_reg=True)

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
# Calculate the EWMA standard deviation for all portfolios using a 21-day halflife
all_portfolio_ewma_returns= all_portfolio_returns.ewm(halflife=21).std()
# Plot the EWMA standard deviation
all_portfolio_ewma_returns.plot(figsize=(20,15), legend=True, title="21-Day Halflife EWMA Returns")
# Out:
# <AxesSubplot:title={'center':'21-Day Halflife EWMA Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
all_portfolio_sharpe_ratio=(all_portfolio_returns.mean() * 252) / (all_portfolio_returns["SP500"].std() * np.sqrt(252))
all_portfolio_sharpe_ratio
# Out:
# SP500                         -0.518582
# SOROS FUND MANAGEMENT LLC      0.315312
# PAULSON & CO.INC.             -0.402066
# TIGER GLOBAL MANAGEMENT LLC   -0.165215
# BERKSHIRE HATHAWAY INC         0.912828
# Algo 1                         1.215802
# Algo 2                         0.470478
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
all_portfolio_sharpe_ratio.plot(kind="bar",title="All Portfolio Sharpe Ratio")
# Out:
# <AxesSubplot:title={'center':'All Portfolio Sharpe Ratio'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock

# %%
# Reading data from 2nd stock

# %%
# Reading data from 3rd stock

# %%
# Combine all stocks in a single DataFrame

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns

# Drop NAs

# Display sample data

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

# Display sample data

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios

# %%
# Visualize the sharpe ratios as a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
